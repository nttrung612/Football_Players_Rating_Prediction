# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('processed data/fe_missForest_data.csv')

# %%
df = df = pd.read_csv('processed data/missForest_data.csv')

# %%
df['value_euro'].hist(bins=20)
# Out:
# <Axes: >

# %%
df['wage_euro'].hist(bins=20)
# Out:
# <Axes: >

# %%
df['release_clause_euro'].hist(bins=20)
# Out:
# <Axes: >

# %%
df['international_reputation(1-5)'].hist()
# Out:
# <Axes: >

# %%
# Tạo đặc trưng phân loại cho value_euro
def value_category(value):
    if value < 1e6:
        return 'Low'
    elif 1e6 <= value < 1e7:
        return 'Medium'
    else:
        return 'High'

df['value_category'] = df['value_euro'].apply(value_category)
# Out:
#   Cell In[12], line 2
#     if value < 1e6:
#                    ^
# SyntaxError: incomplete input
